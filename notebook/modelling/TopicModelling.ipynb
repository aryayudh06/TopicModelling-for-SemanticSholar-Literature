# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
df = pd.read_csv('data_crawl2.csv')
abstracts = df['abstract'].dropna().tolist()  # Ambil kolom 'abstract' dan hilangkan nilai NaN

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Download the necessary data for punkt
nltk.download('punkt_tab')

# Existing code remains the same
stop_words = set(stopwords.words('indonesian'))  # Stopwords dalam bahasa Indonesia

def preprocess(text):
    tokens = word_tokenize(text.lower())
    tokens = [word for word in tokens if word.isalnum() and word not in stop_words]
    return tokens

processed_abstracts = [preprocess(abstract) for abstract in abstracts]
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=1000)
dtm = vectorizer.fit_transform([' '.join(tokens) for tokens in processed_abstracts])

# %%
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
for index, topic in enumerate(lda.components_):
    print(f"Topik {index + 1}:")
    print([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print()
# Out:
# Topik 1:
# ['kualitas', 'produk', 'citra', 'perusahaan', 'pembelian', 'kerja', 'keputusan', 'bertujuan', 'pengaruh', 'penelitian']
#
# Topik 2:
# ['that', 'in', 'and', 'is', 'this', 'to', 'universitas', 'brawijaya', 'the', 'of']
#
# Topik 3:
# ['in', 'faculty', 'mahasiswa', 'komputer', 'administrasi', 'of', 'ilmu', 'fakultas', 'universitas', 'brawijaya']
#
# Topik 4:
# ['universitas', 'brawijaya', 'malang', 'kinerja', 'pertanian', 'brand', 'fakultas', 'ub', 'keuangan', 'penelitian']
#
# Topik 5:
# ['responden', 'data', 'teknik', 'ekonomi', 'sampel', 'malang', 'mahasiswa', 'penelitian', 'brawijaya', 'universitas']

# %%
# !pip install pyLDAvis
# Out:
# Requirement already satisfied: pyLDAvis in /usr/local/lib/python3.11/dist-packages (3.4.1)
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (3.1.5)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.10.2)
# Requirement already satisfied: funcy in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (1.6.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (4.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pyLDAvis) (75.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->pyLDAvis) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim->pyLDAvis) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->pyLDAvis) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim->pyLDAvis) (1.17.2)

# %%
# !pip install pyLDAvis[sklearn]
# Out:
# Requirement already satisfied: pyLDAvis[sklearn] in /usr/local/lib/python3.11/dist-packages (3.4.1)
# WARNING: pyldavis 3.4.1 does not provide the extra 'sklearn'
# Requirement already satisfied: numpy>=1.24.2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (1.13.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (2.2.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (1.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (3.1.5)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (2.10.2)
# Requirement already satisfied: funcy in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (2.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (1.6.1)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (4.3.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from pyLDAvis[sklearn]) (75.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis[sklearn]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis[sklearn]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->pyLDAvis[sklearn]) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->pyLDAvis[sklearn]) (3.5.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim->pyLDAvis[sklearn]) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->pyLDAvis[sklearn]) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->pyLDAvis[sklearn]) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim->pyLDAvis[sklearn]) (1.17.2)

# %%
import pyLDAvis
import pyLDAvis.lda_model
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.lda_model.prepare(lda, dtm, vectorizer)
pyLDAvis.display(vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el6251383362382356324034001588" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el6251383362382356324034001588_data = {"mdsDat": {"x": [0.08381933114805222, -0.30807816715976594, 0.15505456909248277, 0.12544483525323907, -0.056240568334008166], "y": [-0.16785687515800474, 0.048069199986328165, 0.2136317109042218, -0.05241859038805859, -0.04142544534448649], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [28.48493509520948, 24.411883119219517, 18.740777741815922, 16.79492846121568, 11.567475582539405]}, "tinfo": {"Term": ["pengaruh", "universitas", "brawijaya", "bertujuan", "the", "of", "penelitian", "fakultas", "ilmu", "mahasiswa", "keuangan", "to", "keputusan", "this", "sampel", "kerja", "is", "in", "perusahaan", "and", "ub", "pembelian", "citra", "ekonomi", "brand", "malang", "kualitas", "tujuan", "administrasi", "kinerja", "sampel", "teknik", "akuntansi", "faktor", "s1", "populasi", "kampus", "sampling", "ekonomi", "islam", "responden", "layanan", "pengumpulan", "badan", "angkatan", "negeri", "parkir", "kantor", "penulis", "beasiswa", "menyelesaikan", "menempuh", "kuliah", "pertumbuhan", "jawa", "purposive", "sektor", "pengambilan", "kerjasama", "psikologi", "mahasiswa", "orang", "metode", "universitas", "brawijaya", "sistem", "data", "malang", "tingkat", "bisnis", "penelitian", "analisis", "studi", "lingkungan", "hasil", "jurusan", "skripsi", "pendidikan", "karyawan", "fakultas", "pengaruh", "keputusan", "kerja", "citra", "kualitas", "variabel", "wisata", "kepuasan", "bertujuan", "pembelian", "parsial", "explanatory", "mempengaruhi", "persepsi", "dana", "harga", "signifikan", "iklan", "kepercayaan", "menguji", "ternak", "peternakan", "x1", "motivasi", "kemudahan", "penggunaan", "nilai", "indikator", "sikap", "destinasi", "tanaman", "menganalisis", "produk", "tanah", "minat", "perusahaan", "penelitian", "merek", "jenis", "desa", "pengembangan", "indonesia", "tujuan", "salah", "konsumen", "karyawan", "to", "the", "that", "study", "by", "factors", "aims", "is", "sakit", "and", "was", "this", "influence", "one", "endorser", "an", "inclusive", "academic", "campus", "celebrity", "results", "pressure", "education", "abstract", "which", "sample", "as", "with", "food", "inovasi", "of", "students", "on", "rumah", "research", "in", "are", "university", "berkunjung", "peningkatan", "model", "teknologi", "brawijaya", "universitas", "malang", "kegiatan", "informasi", "pendidikan", "perkembangan", "komputer", "faculty", "ilmu", "perpustakaan", "kedokteran", "science", "lingkup", "muncul", "conducted", "sosial", "gizi", "administrasi", "politik", "baca", "koleksi", "alam", "perguruan", "potensi", "ptn", "survey", "buku", "population", "business", "product", "accounting", "student", "laporan", "system", "pangan", "gedung", "fakultas", "filkom", "akademik", "brawijaya", "universitas", "laboratorium", "pajak", "in", "of", "dosen", "who", "tingkat", "studi", "program", "salah", "mahasiswa", "memiliki", "malang", "penelitian", "ub", "university", "proses", "skripsi", "brand", "marketing", "tumbuhan", "purchase", "image", "keuangan", "kecamatan", "hama", "juni", "latar", "ewom", "perbankan", "literasi", "maybelline", "surabaya", "berkarir", "hidup", "switching", "quality", "intention", "perilaku", "pertanian", "rasio", "pemasaran", "ayam", "ac", "memanfaatkan", "dimediasi", "gambaran", "pascasarjana", "penyakit", "situs", "dilaksanakan", "pendapatan", "ub", "kinerja", "bank", "2016", "jurusan", "tujuan", "penelitian", "fakultas", "perusahaan", "kota", "malang", "bisnis", "informasi", "berdasarkan", "lembaga", "perpajakan", "memiliki", "website", "brawijaya", "universitas", "teknologi", "bertujuan"], "Freq": [102.0, 293.0, 288.0, 83.0, 59.0, 77.0, 212.0, 67.0, 38.0, 72.0, 22.0, 26.0, 27.0, 25.0, 29.0, 23.0, 20.0, 27.0, 28.0, 20.0, 25.0, 23.0, 19.0, 26.0, 11.0, 67.0, 18.0, 22.0, 16.0, 18.0, 28.818905808328285, 16.28288375532584, 13.602624648790572, 13.600401986339277, 11.811966730360673, 10.91767522906852, 7.33663969661212, 7.329101144566669, 24.256879634316707, 6.442817529531349, 14.94447726897892 ...

# %% [markdown]
# # BERTOPIC

# %%
# !pip install deepl
# Out:
# Collecting deepl
#   Downloading deepl-1.21.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from deepl) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->deepl) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->deepl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->deepl) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->deepl) (2025.1.31)
# Downloading deepl-1.21.0-py3-none-any.whl (38 kB)
# Installing collected packages: deepl
# Successfully installed deepl-1.21.0

# %%
from bertopic import BERTopic
import pandas as pd
import deepl

# %%
data = pd.read_csv("data_crawl2.csv")

# %%
data2 = data[['title']].copy()

# %%
data2.head()
# Out:
#                                                title
# 0  Faktor-faktor yang mempengaruhi literasi finan...
# 1  … (survei pada mahasiswa sarjana jurusan ilmu ...
# 2  Rancang Bangun Aplikasi Sistem Informasi Manaj...
# 3  [PDF][PDF] Optimasi pemanfaatan energi listrik...
# 4  … consumer review oleh beauty vlogger terhadap...

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl.metadata (909 bytes)
# Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 4.5 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Buat objek stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# Fungsi untuk stemming
def stem_sentence(sentence):
    return stemmer.stem(sentence)

# Terapkan ke DataFrame
data2['Stemmed_Text'] = data2['title'].apply(stem_sentence)

# Lihat hasilnya
print(data2)
# Out:
#                                                  title  \
# 0    Faktor-faktor yang mempengaruhi literasi finan...
# 1    … (survei pada mahasiswa sarjana jurusan ilmu ...
# 2    Rancang Bangun Aplikasi Sistem Informasi Manaj...
# 3    [PDF][PDF] Optimasi pemanfaatan energi listrik...
# 4    … consumer review oleh beauty vlogger terhadap...
# ..                                                 ...
# 405  Pengaruh Good Corporate Governance Dan Profita...
# 406  Pengaruh kepuasan kerja terhadap stres kerja d...
# 407  Evaluasi Usability dan Perbaikan Desain Antarm...
# 408  Pengaruh Kemudahan, Keamanan, Kepercayaan Dan ...
# 409  … Of Use, Behavioral Control, Security And Tru...
#
#                                           Stemmed_Text
# 0    faktor yang pengaruh literasi finansial mahasi...
# 1    survei pada mahasiswa sarjana jurus ilmu admin...
# 2    rancang bangun aplikasi sistem informasi manaj...
# 3    pdf pdf optimasi manfaat energi listrik tenaga...
# 4    consumer review oleh beauty vlogger hadap putu...
# ..                                                 ...
# 405  pengaruh good corporate governance dan profita...
# 406  pengaruh puas kerja hadap stres kerja dan turn...
# 407  evaluasi usability dan baik desain antarmuka g...
# 408  pengaruh mudah aman percaya dan kualitas infor...
# 409  of use behavioral control security and trust t...
#
# [410 rows x 2 columns]

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# Buat stop word remover
factory = StopWordRemoverFactory()
stopword = factory.create_stop_word_remover()

def stop_sentence(sentence):
    return stopword.remove(sentence)

# Terapkan ke DataFrame
data2['Stopped_Text'] = data2['Stemmed_Text'].apply(stop_sentence)

print(data2)
# Out:
#                                                  title  \
# 0    Faktor-faktor yang mempengaruhi literasi finan...
# 1    … (survei pada mahasiswa sarjana jurusan ilmu ...
# 2    Rancang Bangun Aplikasi Sistem Informasi Manaj...
# 3    [PDF][PDF] Optimasi pemanfaatan energi listrik...
# 4    … consumer review oleh beauty vlogger terhadap...
# ..                                                 ...
# 405  Pengaruh Good Corporate Governance Dan Profita...
# 406  Pengaruh kepuasan kerja terhadap stres kerja d...
# 407  Evaluasi Usability dan Perbaikan Desain Antarm...
# 408  Pengaruh Kemudahan, Keamanan, Kepercayaan Dan ...
# 409  … Of Use, Behavioral Control, Security And Tru...
#
#                                           Stemmed_Text  \
# 0    faktor yang pengaruh literasi finansial mahasi...
# 1    survei pada mahasiswa sarjana jurus ilmu admin...
# 2    rancang bangun aplikasi sistem informasi manaj...
# 3    pdf pdf optimasi manfaat energi listrik tenaga...
# 4    consumer review oleh beauty vlogger hadap putu...
# ..                                                 ...
# 405  pengaruh good corporate governance dan profita...
# 406  pengaruh puas kerja hadap stres kerja dan turn...
# 407  evaluasi usability dan baik desain antarmuka g...
# 408  pengaruh mudah aman percaya dan kualitas infor...
# 409  of use behavioral control security and trust t...
#
#                                           Stopped_Text
# 0    faktor pengaruh literasi finansial mahasiswa f...
# 1    survei mahasiswa sarjana jurus ilmu administra...
# 2    rancang bangun aplikasi sistem informasi manaj...
# 3    pdf pdf optimasi manfaat energi listrik tenaga...
# 4    consumer review beauty vlogger hadap putus bel...
# ..                                                 ...
# 405  pengaruh good corporate governance profitabili...
# 406  pengaruh puas kerja hadap stres kerja turnover...
# 407  evaluasi usability baik desain antarmuka situs...
# 408  pengaruh mudah aman percaya kualitas informasi...
# 409  of use behavioral control security and trust t...
#
# [410 rows x 3 columns]

# %%
data2.head()
# Out:
#                                                title  \
# 0  Faktor-faktor yang mempengaruhi literasi finan...
# 1  … (survei pada mahasiswa sarjana jurusan ilmu ...
# 2  Rancang Bangun Aplikasi Sistem Informasi Manaj...
# 3  [PDF][PDF] Optimasi pemanfaatan energi listrik...
# 4  … consumer review oleh beauty vlogger terhadap...
#
#                                         Stemmed_Text  \
# 0  faktor yang pengaruh literasi finansial mahasi...
# 1  survei pada mahasiswa sarjana jurus ilmu admin...
# 2  rancang bangun aplikasi sistem informasi manaj...
# 3  pdf pdf optimasi manfaat energi listrik tenaga...
# 4  consumer review oleh beauty vlogger hadap putu...
#
#                                         Stopped_Text
# 0  faktor pengaruh literasi finansial mahasiswa f...
# 1  survei mahasiswa sarjana jurus ilmu administra...
# 2  rancang bangun aplikasi sistem informasi manaj...
# 3  pdf pdf optimasi manfaat energi listrik tenaga...
# 4  consumer review beauty vlogger hadap putus bel...

# %%
model = BERTopic()

# %%
topics,prob = model.fit_transform(data2['Stopped_Text'])
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling%2Fconfig.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
model.get_topic_info()
# Out:
#    Topic  Count                                        Name  \
# 0     -1     44          -1_hadap_studi_ekonomi_universitas
# 1      0    142       0_universitas_brawijaya_ilmu_fakultas
# 2      1    108                1_pengaruh_hadap_usaha_tanam
# 3      2     40                   2_hadap_brand_beli_survei
# 4      3     25     3_kabupaten_kembang_pariwisata_analisis
# 5      4     20       4_pdf_universitas_brawijaya_mahasiswa
# 6      5     18  5_pengaruh_mahasiswa_brawijaya_universitas
# 7      6     13          6_kerja_karyawan_motivasi_pengaruh
#
#                                       Representation  \
# 0  [hadap, studi, ekonomi, universitas, brawijaya...
# 1  [universitas, brawijaya, ilmu, fakultas, admin...
# 2  [pengaruh, hadap, usaha, tanam, studi, indones...
# 3  [hadap, brand, beli, survei, pengaruh, putus, ...
# 4  [kabupaten, kembang, pariwisata, analisis, bud...
# 5  [pdf, universitas, brawijaya, mahasiswa, trans...
# 6  [pengaruh, mahasiswa, brawijaya, universitas, ...
# 7  [kerja, karyawan, motivasi, pengaruh, hadap, o...
#
#                                  Representative_Docs
# 0  [beli produk kosmetik sertifikat halal mui stu...
# 1  [sikap e-learning survei mahasiswa jurus admin...
# 2  [pengaruh ukur usaha profitabilitas leverage n...
# 3  [pengaruh brand image hadap putus beli survei ...
# 4  [rencana kembang wisata daerah studi dinas pem...
# 5  [pdf pdf minat mahasiswa program studi paja be...
# 6  [pengaruh alam magang minat kerja hadap kesiap...
# 7  [pengaruh work family conflict hadap kerja kar...

# %%
model.visualize_barchart()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="25bea63c-7e6b-4bcc-8530-e8495ca17f4c" class="plotly-graph-div" style="height:500px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25bea63c-7e6b-4bcc-8530-e8495ca17f4c")) {                    Plotly.newPlot(                        "25bea63c-7e6b-4bcc-8530-e8495ca17f4c",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.06377240062385837,0.07343218599686903,0.07426580918176129,0.10228335243812163,0.10300365773698164],"y":["administrasi  ","fakultas  ","ilmu  ","brawijaya  ","universitas  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.034971895050207924,0.03581623295730595,0.039556078155484974,0.07369497902007804,0.08426404629376338],"y":["studi  ","tanam  ","usaha  ","hadap  ","pengaruh  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.0616797636159304,0.07550960371769809,0.08126902294671184,0.08225770714143661,0.08503858794610092],"y":["pengaruh  ","survei  ","beli  ","brand  ","hadap  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.06519799747160207,0.07192208312789371,0.07854993698657502,0.08082843230064597,0.09255313059403421],"y":["budaya  ","analisis  ","pariwisata  ","kembang  ","kabupaten  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.04241005062801029,0.07469136627299235,0.09117670944279628,0.09117670944279628,0.35484650227168296],"y":["transportasi  ","mahasiswa  ","brawijaya  ","universitas  ","pdf  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.09074281144371973,0.10134781647227158,0.10134781647227158,0.10566623566182835,0.117953332811341],"y":["kerja  ","universitas  ","brawijaya  ","mahasiswa  ","pengaruh  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.0757555294203105,0.09785731727527419,0.1391240230089146,0.16264834767880335,0.20683738057176926],"y":["hadap  ","pengaruh  ","motivasi  ","karyawan  ","kerja  "],"type":"bar","xaxis":"x7","yaxis":"y7"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewid ...

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d5fc71e6-03ed-417a-a6f6-4bfeddf9e833" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5fc71e6-03ed-417a-a6f6-4bfeddf9e833")) {                    Plotly.newPlot(                        "d5fc71e6-03ed-417a-a6f6-4bfeddf9e833",                        [{"customdata":[[0,"universitas | brawijaya | ilmu | fakultas | administrasi",142],[1,"pengaruh | hadap | usaha | tanam | studi",108],[2,"hadap | brand | beli | survei | pengaruh",40],[3,"kabupaten | kembang | pariwisata | analisis | budaya",25],[4,"pdf | universitas | brawijaya | mahasiswa | transportasi",20],[5,"pengaruh | mahasiswa | brawijaya | universitas | kerja",18],[6,"kerja | karyawan | motivasi | pengaruh | hadap",13]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[142,108,40,25,20,18,13],"sizemode":"area","sizeref":0.08875,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[6.4475193,-7.9215956,-8.192714,-7.519582,6.0610447,7.160433,7.6899524],"xaxis":"x","y":[4.7130103,12.622921,12.894538,12.22105,4.1864734,4.4715314,4.4431105],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666 ...
